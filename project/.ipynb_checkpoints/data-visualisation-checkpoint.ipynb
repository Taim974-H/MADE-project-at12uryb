# %%
import requests
import os
import pandas as pd
import numpy as np
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# %%
con = sqlite3.connect("data/emissions.sqlite")
con2 = sqlite3.connect("data/generate_waste.sqlite")
con3 = sqlite3.connect("data/treat_waste.sqlite")

df_emissions = pd.read_sql_query("SELECT * from emissions", con)
con.close()

df_generate_waste = pd.read_sql_query("SELECT * from generate_waste", con2)
con2.close()

df_treat_waste = pd.read_sql_query("SELECT * from treat_waste", con3)
con3.close()

# %% [markdown]
# ## Database visualisation

# %% [markdown]
# ### Emissions table

# %%
df_emissions = df_emissions.drop(['index','Name'], axis=1)
df_emissions.head(5)
# Out:
#                                      Emission Sector    Y_2004    Y_2005  \
# 0                     Emissions from biomass burning  0.454820  0.354977
# 1             Incineration and Open Burning of Waste  0.000893  0.000568
# 2      Main Activity Electricity and Heat Production  0.581944  0.603752
# 3  Petroleum Refining - Manufacture of Solid Fuel...  0.100303  0.105945
# 4          Manufacturing Industries and Construction  1.838147  1.874918
#
#      Y_2006    Y_2007    Y_2008    Y_2009    Y_2010    Y_2011    Y_2012  \
# 0  0.353629  0.350116  0.401103  0.376501  0.372729  0.427636  0.386539
# 1  0.000585  0.000023  0.000022  0.000023  0.000043  0.000147  0.000036
# 2  0.646378  0.670161  0.702585  0.669695  0.682530  0.597664  0.616068
# 3  0.104584  0.098223  0.099935  0.087664  0.100346  0.062978  0.068637
# 4  1.884185  1.821839  1.746298  1.346745  1.362954  1.435442  1.509525
#
#      Y_2013    Y_2014    Y_2015    Y_2016    Y_2017    Y_2018
# 0  0.492477  0.504074  0.513859  0.445393  0.455365  0.366924
# 1  0.000025  0.000013  0.000014  0.000015  0.000016  0.000017
# 2  0.565305  0.559873  0.570135  0.613571  0.609766  0.586702
# 3  0.069599  0.068002  0.095377  0.085655  0.093195  0.095093
# 4  1.483011  1.629930  1.720960  1.755933  1.864889  1.851044

# %%
# To check all columns are numeric

sliced_df = df_emissions.iloc[1:, 2:]
# Convert to numeric and keep track of non-numeric columns
numeric_df = sliced_df.apply(pd.to_numeric, errors='coerce')

# Identify columns with any NaN values
non_numeric_columns = numeric_df.columns[numeric_df.isnull().any()].tolist()
if non_numeric_columns:
    print("Columns with non-numeric data:", non_numeric_columns)
else:
    print("All columns have numeric data.")
# Out:
# All columns have numeric data.

# %%
#Before removing the null 
print ("Before removing the empty cells")
nn = df_emissions.isnull().sum()
print(nn)

#After Removing the empty cells
print ("After Removing the empty Cells")
df_emissions.dropna(inplace=True)
nn = df_emissions.isnull().sum()
nn
# Out:
# Before removing the empty cells
# Emission Sector    0
# Y_2004             0
# Y_2005             0
# Y_2006             0
# Y_2007             0
# Y_2008             0
# Y_2009             0
# Y_2010             0
# Y_2011             0
# Y_2012             0
# Y_2013             0
# Y_2014             0
# Y_2015             0
# Y_2016             0
# Y_2017             0
# Y_2018             0
# dtype: int64
# After Removing the empty Cells
# Emission Sector    0
# Y_2004             0
# Y_2005             0
# Y_2006             0
# Y_2007             0
# Y_2008             0
# Y_2009             0
# Y_2010             0
# Y_2011             0
# Y_2012             0
# Y_2013             0
# Y_2014             0
# Y_2015             0
# Y_2016             0
# Y_2017             0
# Y_2018             0
# dtype: int64

# %%
# Set 'Emission Sector' as the index
df = df_emissions
df.set_index('Emission Sector', inplace=True)

# Creating heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df, annot=True, cmap='coolwarm')
plt.title('Heatmap of Ireland Data Over Years')
plt.show()

# %% [markdown]
# ### Generate waste table

# %%
df_generate_waste.head(20)
# Out:
#     index  Year                   NACE Rev. 2 Activity  \
# 0       3  2004  Agriculture, forestry and fishing (A)
# 1       4  2004  Agriculture, forestry and fishing (A)
# 2       5  2004  Agriculture, forestry and fishing (A)
# 3       6  2004  Agriculture, forestry and fishing (A)
# 4       7  2004  Agriculture, forestry and fishing (A)
# 5       8  2004  Agriculture, forestry and fishing (A)
# 6      10  2004  Agriculture, forestry and fishing (A)
# 7      11  2004  Agriculture, forestry and fishing (A)
# 8      15  2004  Agriculture, forestry and fishing (A)
# 9      16  2004  Agriculture, forestry and fishing (A)
# 10     17  2004  Agriculture, forestry and fishing (A)
# 11     18  2004  Agriculture, forestry and fishing (A)
# 12     19  2004  Agriculture, forestry and fishing (A)
# 13     20  2004  Agriculture, forestry and fishing (A)
# 14     21  2004  Agriculture, forestry and fishing (A)
# 15     22  2004  Agriculture, forestry and fishing (A)
# 16     23  2004  Agriculture, forestry and fishing (A)
# 17     24  2004  Agriculture, forestry and fishing (A)
# 18     25  2004  Agriculture, forestry and fishing (A)
# 19     26  2004  Agriculture, forestry and fishing (A)
#
#                                     Hazardousness  \
# 0   Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 1   Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 2   Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 3   Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 4   Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 5   Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 6   Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 7   Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 8   Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 9   Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 10  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 11  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 12  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 13  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 14  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 15  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 16  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 17  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 18  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 19  Hazardous and non-hazardous - Total[HAZ_NHAZ]
#
#                                        Waste Category   VALUE
# 0      Chemical and medical wastes (subtotal)[W01-05]     0.0
# 1                                Spent solvents[W011]     0.0
# 2               Acid, alkaline or saline wastes[W012]     0.0
# 3                                     Used oils[W013]     0.0
# 4                               Chemical wastes[W02A]     0.0
# 5                   Industrial effluent sludges[W032]     0.0
# 6              Health care and biological wastes[W05]     0.0
# 7   Recyclable wastes (subtotal, W06+W07 except W0...  8706.0
# 8                                  Glass wastes[W071]     0.0
# 9                    Paper and cardboard wastes[W072]     0.0
# 10                                Rubber wastes[W073]     0.0
# 11                               Plastic wastes[W074]  8706.0
# 12                                  Wood wastes[W075]     0.0
# 13                               Textile wastes[W076]     0.0
# 14  Equipment (subtotal, W077+W08A+W081+W0841)[W07...     0.0
# 15                         Waste containing PCB[W077]     0.0
# 16  Discarded equipment (except discarded vehicles...     0.0
# 17                           Discarded vehicles[W081]     0.0
# 18           Batteries and accumulators wastes[W0841]     0.0
# 19  Animal and vegetal wastes (subtotal, W091+W092...     0.0

# %% [markdown]
# ### Treat waste table

# %%
df_treat_waste.head(20)
# Out:
#     index  Year                                  Hazardousness  \
# 0       9  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 1      10  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 2      11  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 3      12  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 4      13  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 5      14  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 6      15  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 7      36  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 8      37  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 9      38  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 10     39  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 11     40  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 12     41  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 13     42  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 14     72  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 15     75  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 16     77  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 17     81  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 18     87  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
# 19    117  2004  Hazardous and non-hazardous - Total[HAZ_NHAZ]
#
#                                        Waste Category  \
# 0      Chemical and medical wastes (subtotal)[W01-05]
# 1      Chemical and medical wastes (subtotal)[W01-05]
# 2      Chemical and medical wastes (subtotal)[W01-05]
# 3      Chemical and medical wastes (subtotal)[W01-05]
# 4      Chemical and medical wastes (subtotal)[W01-05]
# 5      Chemical and medical wastes (subtotal)[W01-05]
# 6      Chemical and medical wastes (subtotal)[W01-05]
# 7                                     Used oils[W013]
# 8                                     Used oils[W013]
# 9                                     Used oils[W013]
# 10                                    Used oils[W013]
# 11                                    Used oils[W013]
# 12                                    Used oils[W013]
# 13                                    Used oils[W013]
# 14             Health care and biological wastes[W05]
# 15             Health care and biological wastes[W05]
# 16             Health care and biological wastes[W05]
# 17  Recyclable wastes (subtotal, W06+W07 except W0...
# 18  Recyclable wastes (subtotal, W06+W07 except W0...
# 19                                 Glass wastes[W071]
#
#                            Waste Management Operation     VALUE
# 0                            All Waste treatment[TRT]  102445.0
# 1   Disposal - landfill and other (D1-D7, D12)[DSP...   33887.0
# 2            Disposal - landfill (D1, D5, D12)[DSP_L]   33887.0
# 3                Disposal - incineration (D10)[DSP_I]   37390.0
# 4            Disposal - other (D2-D4, D6-D7)[DSP_OTH]       0.0
# 5              Recovery - energy recovery (R1)[RCV_E]    9965.0
# 6   Recovery - recycling and backfilling (R2-R11)[...   21203.0
# 7                            All Waste treatment[TRT]   21221.0
# 8   Disposal - landfill and other (D1-D7, D12)[DSP...      18.0
# 9            Disposal - landfill (D1, D5, D12)[DSP_L]      18.0
# 10               Disposal - incineration (D10)[DSP_I]       0.0
# 11           Disposal - other (D2-D4, D6-D7)[DSP_OTH]       0.0
# 12             Recovery - energy recovery (R1)[RCV_E]       0.0
# 13  Recovery - recycling and backfilling (R2-R11)[...   21203.0
# 14                           All Waste treatment[TRT]       0.0
# 15               Disposal - incineration (D10)[DSP_I]       0.0
# 16             Recovery - energy recovery (R1)[RCV_E]       0.0
# 17                           All Waste treatment[TRT]  308012.0
# 18  Recovery - recycling and backfilling (R2-R11)[...  308012.0
# 19                           All Waste treatment[TRT]    3124.0

# %% [markdown]
# ## Graphs

# %%
# Calculate the total waste generated for each year
total_waste_gen_by_year = df_generate_waste.groupby('Year')['VALUE'].sum()
# Calculate the total waste treated for each year
total_waste_treat_by_year = df_treat_waste.groupby('Year')['VALUE'].sum()
waste_emissions_df = df_emissions[df_emissions['Emission Sector'].isin(['Solid Waste Disposal', 
                                                             'Incineration and Open Burning of Waste', 
                                                             'Biological Treatment of Solid Waste'])]

# Now, let's calculate the total waste emissions for each year
waste_emissions_by_year = waste_emissions_df.iloc[:, 1:].sum()
# Now, let's calculate the total emissions for all sectors for each year
total_emissions_by_year = df_emissions.iloc[:, 1:].sum()

# %%
#trend of total waste generation over time
plt.plot(total_waste_gen_by_year.index, total_waste_gen_by_year.values, marker='o', linestyle='-', label='Generation')
plt.plot(total_waste_treat_by_year.index, total_waste_treat_by_year.values, marker='o', linestyle='-', color='red', label='Treatment')
plt.title('Comparison of Total Waste Generation and Treatment in Ireland')
plt.xlabel('Year')
plt.ylabel('Total Waste (t)')
plt.legend()
plt.grid(True)

# %%
#trend of total emissions and waste emissions over time
plt.plot(total_emissions_by_year.index, total_emissions_by_year.values, marker='o', linestyle='-', label='Total Emissions')
plt.plot(waste_emissions_by_year.index, waste_emissions_by_year.values, marker='o', linestyle='-', label='Waste Sector Emissions')
plt.title('Trend of Total (NMVOC) Emissions and Waste Sector Emissions in Ireland')
plt.xlabel('Year')
plt.ylabel('Emissions (t)')
plt.legend()
plt.grid(True)
plt.xticks(total_emissions_by_year.index)
plt.tick_params(axis='x', rotation=45)
